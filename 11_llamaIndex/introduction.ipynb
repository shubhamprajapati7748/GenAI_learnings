# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["HF_TOKEN"]=os.getenv("HUGGINGFACE_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
groq_api_key=os.getenv("GROQ_API_KEY")

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, Settings
from llama_index.llms.ollama import Ollama
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.llms.groq import Groq

# %% [markdown]
# ## Prompt Template

# %%
embed_model = HuggingFaceEmbedding(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# d:\_GENAI\GenAI_learnings\genaivenv\Lib\site-packages\huggingface_hub\file_download.py:140: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Shubh\AppData\Local\llama_index\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)

# %%
# llm = Groq(model="llama3-70b-8192",api_key=groq_api_key)
llm = Groq(model="llama3-70b-8192",api_key="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")

# %%
# Set global settings
Settings.llm = llm
Settings.embed_model = embed_model

# %%
response = llm.complete("Explain the importance of low latency LLMs")

# %%
response.text
# Out:
# 'Low-latency Large Language Models (LLMs) are crucial in various applications where real-time or near-real-time processing are essential. Here are some reasons why low-latency LLMs are important:\n\n1. **Conversational AI**: In conversational AI, such as chatbots, voice assistants, or dialogue systems, low-latency LLMs enable rapid response times, making the interaction feel more natural and engaging. Delays in response can lead to user frustration and abandonment.\n2. **Real-time language translation**: Low-latency LLMs are essential for simultaneous translation in applications like video conferencing, live subtitles, or real-time chat translation. This enables seamless communication across language barriers.\n3. **Speech recognition**: Fast and accurate speech recognition is critical in applications like voice-controlled devices, voice assistants, or transcription services. Low-latency LLMs help improve the user experience by providing rapid and accurate speech-to-text conversion.\n5. **Gaming and simulation**: In online gaming, low-latency LLMs can enhance the gaming experience by enabling rapid processing of player inputs, and generating responsive and realistic game environments. In simulation-based training, low-latency LLMs can improve the realism and effectiveness of the training experience.\n6. **Healthcare and telemedicine**: In telemedicine, low-latency LLMs can facilitate real-time language translation, enabling doctors to communicate more effectively with non-native speakers. This can lead to better health outcomes and improved patient satisfaction.\n7. **Customer service**: Low-latency LLMs can power chatbots and virtual assistants that provide rapid and accurate responses to customer inquiries, reducing wait times, and improving overall customer experience.\n8. **Edge AI**: With the proliferation of edge devices, low-latency LLMs can be deployed at the edge, reducing latency and improving performance in applications like autonomous vehicles, smart homes, or smart cities.\n9. **Real-time sentiment analysis**: Low-latency LLMs can analyze social media posts, customer feedback, or other text data in real-time, providing insights that can inform business decisions**, improve customer satisfaction, and mitigate potential crises.\n\nTo achieve low latency in LLMs, various techniques can be employed, such as:\n\n1. **Model pruning**: Reducing the model size and complexity to improve inference speed.\n2. **Quantization**: Representing model weights and activations using fewer bits to reduce memory usage and improve inference speed.\n3. **Knowledge distillation**: Training smaller models to mimic the behavior of larger, more accurate models.\n4. **Parallel processing**: Distributing the model across multiple devices or cores to accelerate inference.\n5. **Efficient algorithms**: Developing algorithms that can process input data more efficiently, such as using sparse attention mechanisms or hierarchical processing.\n\nBy reducing latency, low-latency LLMs can unlock new applications, improve user experiences, and drive business value in various industries.'

# %% [markdown]
# ## llama-index

# %%
from llama_index.core.llms import ChatMessage

messages = [
    ChatMessage(
        role="system", content="You are a pirate with a colorful personality"
    ),
    ChatMessage(role="user", content="What is your name"),
]
resp = llm.stream_chat(messages)
resp
# Out:
# <generator object llm_chat_callback.<locals>.wrap.<locals>.wrapped_llm_chat.<locals>.wrapped_gen at 0x000001D507547640>

# %%
for r in resp:
    print(r.delta, end="")
# Out:
# Arrr, me hearty! Me name be Captain Zephyr "Blackheart" McSnively, the most feared and revered pirate to ever sail the seven seas! Me reputation precedes me, and me exploits be the stuff o' legend! Me ship, the "Maverick's Revenge", be me home, me pride, and me ticket to adventure and riches! So, what be bringin' ye to these fair waters? Are ye lookin' to join me crew, or are ye lookin' to walk the plank?

# %% [markdown]
# ## Llama-index RAG

# %%
documents = SimpleDirectoryReader("../datasets").load_data()
index = VectorStoreIndex.from_documents(documents)
# Out:
# Failed to load file d:\_GENAI\GenAI_learnings\11_llamaIndex\..\datasets\sentiment_analysis.csv with error: 'utf-8' codec can't decode byte 0xb2 in position 86: invalid start byte. Skipping...

# %%
query_engine = index.as_query_engine()

# %%
response = query_engine.query("Summarize the documents.")
print(response)
# Out:
# The documents appear to be related to language models, artificial intelligence, and their applications. The papers discuss various topics such as the development of language models like Llama, their capabilities, and their potential risks and limitations. Some papers focus on the safety and ethical considerations of these models, including their potential impact on the labor market and the environment. Others explore the use of these models in specific applications like Starcraft II and chatbots. The documents also discuss the importance of responsible release strategies and the need for further research in this area.

# %% [markdown]
# ## Agent

# %%
from llama_index.core.agent.workflow import FunctionAgent

# %%
def multiply(a: float, b: float) -> float:
    """Multiply two numbers and returns the product"""
    return a * b


def add(a: float, b: float) -> float:
    """Add two numbers and returns the sum"""
    return a + b

# %%
workflow = FunctionAgent(
    tools=[multiply, add],
    llm=llm,
    system_prompt="You are an agent that can perform basic mathematical operations using tools.",
)

# %%
response = await workflow.run(user_msg="What is 20+(2*4)?")
print(response)
# Out:
# 28

# %% [markdown]
# ## llama-index evaluation
# 1. eco-system
# 2. speed
# 3. community support
# 4. enterprise uses
# 5. functionality
# 6. simplicity
